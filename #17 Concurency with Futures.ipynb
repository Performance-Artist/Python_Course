# %%
# Concurency with Futures.

# %%
# Usually programs are executed sequentially - one task at a time.
# However it is possible to execute many task at one moment. Actually you are still executing
# still one task ot a time, but when the CPU is waiting for a response from an external resource
# it is performing another task.

# %%
# concurrent.futures is a module that allows you to create this virtulization of parallel tasks.

# %%
# Let's see an example:
# We will do the same thing as in the last lecture but will try to make it concurent.

# %%
# Firstly let's try load our list of ids.

# %%
import json
albums_id = json.load(open('albums_ids.json', 'r'))

# %%
albums_id
# Out:
# ['6VH2op0GKIl3WNTbZmmcmI',
#  '23FJTTzUIUjhmimOE2CTX2',
#  '0kTe1sQd9yhDsdG2Zth7X6',
#  '4wExFfncaUIqSgoxnqa3Eh',
#  '3otvl9PN3kOgk5uwAh1CBL',
#  '56G9UnPmRifbubzPDJfAyd',
#  '228mANuRrV20jS5DCA0eER',
#  '5WRmchevXvk5eXPT0gEuTL',
#  '1jCYuXr0Ujke24z1ymBr5U',
#  '1W5CtQ7Ng0kP3lXyz7PIT2',
#  '4wVHvawxZy52Oemd4sGyUm',
#  '0ui4S0TZghkf1d1Wz0oWpk',
#  '6vSiY2OVanKKforfEOT2PD',
#  '3uhD8hNpb0m3iIZ18RHH5u',
#  '3xiPkaTzfC48CcsXYgz5v0',
#  '1lZahjeu4AhPkg9JARZr5F',
#  '0ovKDDAHiTwg4AEjKdgdWo',
#  '4Q7cPyiP8cMIlUEHAqeYfd',
#  '26tH0kjUhkxBEd3ipGkx3Y',
#  '7gS8ozSkvPW3VBPLnXOZ7S']

# %%
# Now as the last time we must autentificate ourselves on spotify.
import requests

# %%
# Now we need to setup the CLIENT_ID and the CLIENT_SECRET
CLIENT_ID = '1e8df497a8254e4b8ee14e464f164d71'
CLIENT_SECRET = 'bfaa9a12282640d1b38c2f145ede3ef5'

# %%
# To get the data from spotify we must firstly autetithicate ourselves, let's define the 
# Autehtification url
AUTH_URL = 'https://accounts.spotify.com/api/token'

# %%
# Now we can send the aiutetification request
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# %%
# Now we must use the json funtion to convert the response into json format
auth_response_data = auth_response.json()

# %%
# Now we can get the accese token to get the data
access_token = auth_response_data['access_token']

# %%
# Let's extract the headers
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# Now we must create a function that will request the tracks and will add it to a global variable

# %%
TRACKS_NAMES = []
BASE_URL = 'https://api.spotify.com/v1/'

# %%
def get_tracks(album_id):
    r = requests.get(BASE_URL + 'albums/' + album_id + '/tracks', 
                headers=headers)
    print(r.json())
    data = r.json()['items']
    return [track['name'] for track in data]

# %%
# Now we can import the modules for concurency

# %%
from concurrent import futures

# %%
# let't set the maximal number and the real number of worker threads. To not create unnecessary
# threads.
MAX_WORKERS = 20
workers = min(MAX_WORKERS, len(albums_id))

# %%
# Now we can start the conciurent task
with futures.ThreadPoolExecutor(workers) as executor:
    to_do = []
    for album_id in sorted(albums_id):
        future = executor.submit(get_tracks, album_id)
        to_do.append(future)
    results = []
    for future in futures.as_completed(to_do):
        res = future.result()
        TRACKS_NAMES.extend(res)

# %%
TRACKS_NAMES
# Out:
# ['Good Times Bad Times - Live: O2 Arena, London - December 10, 2007',
#  'Ramble On - Live: O2 Arena, London - December 10, 2007',
#  'Black Dog - Live: O2 Arena, London - December 10, 2007',
#  'In My Time of Dying - Live: O2 Arena, London - December 10, 2007',
#  'For Your Life - Live: O2 Arena, London - December 10, 2007',
#  'Trampled Under Foot - Live: O2 Arena, London - December 10, 2007',
#  "Nobody's Fault but Mine - Live: O2 Arena, London - December 10, 2007",
#  'No Quarter - Live: O2 Arena, London - December 10, 2007',
#  "Since I've Been Loving You - Live: O2 Arena, London - December 10, 2007",
#  'Dazed and Confused - Live: O2 Arena, London - December 10, 2007',
#  'Stairway to Heaven - Live: O2 Arena, London - December 10, 2007',
#  'The Song Remains the Same - Live: O2 Arena, London - December 10, 2007',
#  'Misty Mountain Hop - Live: O2 Arena, London - December 10, 2007',
#  'Kashmir - Live: O2 Arena, London - December 10, 2007',
#  'Whole Lotta Love - Live: O2 Arena, London - December 10, 2007',
#  'Rock and Roll - Live: O2 Arena, London - December 10, 2007',
#  'In the Evening - Remaster',
#  'South Bound Saurez - Remaster',
#  'Fool in the Rain - Remaster',
#  'Hot Dog - Remaster',
#  'Carouselambra - Remaster',
#  'All My Love - Remaster',
#  "I'm Gonna Crawl - Remaster",
#  "We're Gonna Groove - Remaster",
#  'Poor Tom - Remaster',
#  "I Can't Quit You Baby - Remaster",
#  "Walter's Walk - Remaster",
#  'Ozone Baby - Remaster',
#  'Darlene - Remaster',
#  "Bonzo's Montreux - Remaster",
#  'Wearing and Tearing - Remaster',
#  'Achilles Last Stand - 1990 Remaster',
#  'For Your Life - 1990 Remaster',
#  'Royal Orleans - 1993 Remaster',
#  "Nobody's Fault but Mine - 1990 Remaster",
#  'Candy Store Rock - 1990 Remaster',
#  'Hots on for Nowhere - 1993 Remaster',
#  'Tea for One - 1993 Remaster',
#  'In the Evening - Remaster',
#  'South Bound Saurez - Remaster',
#  'Fool in the Rain - Remaster',
#  'Hot Dog - Remaster',
#  'Carouselambra - Remaster',
#  'All My Love - Remaster',
#  "I'm Gonna Crawl - Remaster",
#  'In the Evening - Rough Mix',
#  'Southbound Piano (South Bound Saurez) - Rough Mix',
#  'Fool in the Rain - Rough Mix',
#  'Hot Dog - Rough Mix',
#  'The Epic (Carouselambra) - Rough Mix',
#  'The Hook (All My Love) - Rough Mix',
#  "Blot (I'm Gonna Crawl) - Rough Mix",
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'Brandy & Coke - Trampled Under Foot; Initial / Rough Mix',
#  'Sick Again - Early Version',
#  'In My Time of Dying - Initial / Rough Mix',
#  'Houses of the Holy - Rough Mix with Overdubs',
#  'Everybody Makes It Through - In the Light; Early Version / In Transit',
#  'Rock and Roll - (Live at MSG 1973) [Remaster]',
#  'Celebration Day - (Live at MSG 1973) [Remaster]',
#  'Black Dog - (Live at MSG 1973) [Remaster]',
#  'Over the Hills and Far Away - (Live at MSG 1973) [Remaster]',
#  'Misty Mountain Hop - (Live at MSG 1973) [Remaster]',
#  "Since I've Been Loving You - (Live at MSG 1973) [Remaster]",
#  'No Quarter - (Live at MSG 1973) [Remaster]',
#  'The Song Remains the Same - (Live at MSG 1973) [Remaster]',
#  'The Rain Song - (Live at MSG 1973) [Remaster]',
#  'The Ocean - Live at MSG 1973; 2018 Remaster',
#  'Dazed and Confused - (Live at MSG 1973) [Remaster]',
#  'Stairway to Heaven - (Live at MSG 1973) [Remaster]',
#  'Moby Dick - (Live at MSG 1973) [Remaster]',
#  'Heartbreaker - (Live at MSG 1973) [Remaster]',
#  'Whole Lotta Love - (Live at MSG 1973) [Remaster]',
#  'Achilles Last Stand - Remaster',
#  'For Your Life - Remaster',
#  'Royal Orleans - Remaster',
#  "Nobody's Fault but Mine - Remaster",
#  'Candy Store Rock - Remaster',
#  'Hots on for Nowhere - Remaster',
#  'Tea for One - Remaster',
#  'Two Ones Are Won - Achilles Last Stand Reference Mix',
#  'For Your Life - Reference Mix',
#  '10 Ribs & All / Carrot Pod Pod (Pod) - Reference Mix',
#  'Royal Orleans - Reference Mix',
#  'Hots on for Nowhere - Reference Mix',
#  'Achilles Last Stand - Remaster',
#  'For Your Life - Remaster',
#  'Royal Orleans - Remaster',
#  "Nobody's Fault but Mine - Remaster",
#  'Candy Store Rock - Remaster',
#  'Hots on for Nowhere - Remaster',
#  'Tea for One - Remaster',
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'Custard Pie - 1990 Remaster',
#  'The Rover - 1993 Remaster',
#  'In My Time of Dying - 1990 Remaster',
#  'Houses of the Holy - 1990 Remaster',
#  'Trampled Under Foot - 1990 Remaster',
#  'Kashmir - 1990 Remaster',
#  'In the Light - 1990 Remaster',
#  'Bron-Yr-Aur - 1993 Remaster',
#  'Down by the Seaside - 1993 Remaster',
#  'Ten Years Gone - 1990 Remaster',
#  'Night Flight - 1993 Remaster',
#  'The Wanton Song - 1990 Remaster',
#  'Boogie with Stu - 1993 Remaster',
#  'Black Country Woman - 1993 Remaster',
#  'Sick Again - 1993 Remaster',
#  'In the Evening - 1990 Remaster',
#  'South Bound Saurez - 1993 Remaster',
#  'Fool in the Rain - 1990 Remaster',
#  'Hot Dog - 1993 Remaster',
#  'Carouselambra - 1993 Remaster',
#  'All My Love - 1990 Remaster',
#  "I'm Gonna Crawl - 1990 Remaster",
#  'Custard Pie - 1990 Remaster',
#  'The Rover - 1993 Remaster',
#  'In My Time of Dying - 1990 Remaster',
#  'Houses of the Holy - 1990 Remaster',
#  'Trampled Under Foot - 1990 Remaster',
#  'Kashmir - 1990 Remaster',
#  'In the Light - 1990 Remaster',
#  'Bron-Yr-Aur - 1993 Remaster',
#  'Down by the Seaside - 1993 Remaster',
#  'Ten Years Gone - 1990 Remaster',
#  'Night Flight - 1993 Remaster',
#  'The Wanton Song - 1990 Remaster',
#  'Boogie with Stu - 1993 Remaster',
#  'Black Country Woman - 1993 Remaster',
#  'Sick Again - 1993 Remaster',
#  'The Song Remains the Same - Remaster',
#  'The Rain Song - Remaster',
#  'Over the Hills and Far Away - Remaster',
#  'The Crunge - Remaster',
#  'Dancing Days - Remaster',
#  "D'yer Mak'er - Remaster",
#  'No Quarter - Remaster',
#  'The Ocean - Remaster',
#  'The Song Remains the Same - Guitar Overdub Reference Mix',
#  'The Rain Song - Mix Minus Piano',
#  'Over the Hills and Far Away - Guitar Mix Backing Track',
#  'The Crunge - Rough Mix - Keys Up',
#  'Dancing Days - Rough Mix with Vocal',
#  'No Quarter - Rough Mix with JPJ Keyboard Overdubs - No Vocal',
#  'The Ocean - Working Mix',
#  'LA Drone - Live 1972; 2018 Remaster',
#  'Immigrant Song - Live 1972; 2018 Remaster',
#  'Heartbreaker - Live 1972; 2018 Remaster',
#  'Black Dog - Live 1972; 2018 Remaster',
#  'Over the Hills and Far Away - Live 1972; 2018 Remaster',
#  "Since I've Been Loving You - Live 1972; 2018 Remaster",
#  'Stairway to Heaven - Live 1972; 2018 Remaster',
#  'Going to California - Live 1972; 2018 Remaster',
#  "That's The Way - Live 1972; 2018 Remaster",
#  'Bron-Y-Aur Stomp - Live 1972; 2018 Remaster',
#  'Dazed and Confused - Live 1972; 2018 Remaster',
#  'What Is and What Should Never Be (Live) - Live 1972; 2018 Remaster',
#  'Dancing Days - Live 1972; 2018 Remaster',
#  'Moby Dick - Live 1972; 2018 Remaster',
#  'Whole Lotta Love - Live 1972; 2018 Remaster',
#  'Rock and Roll - Live 1972; 2018 Remaster',
#  'The Ocean - Live 1972; 2018 Remaster',
#  'Bring It on Home / Bring It on Back - Live 1972; 2018 Remaster',
#  'Good Times Bad Times - Remaster',
#  'Communication Breakdown - Remaster',
#  'Dazed and Confused - Remaster',
#  "Babe I'm Gonna Leave You - Remaster",
#  'Whole Lotta Love - Remaster',
#  'Ramble On - Remaster',
#  'Heartbreaker - Remaster',
#  'Immigrant Song - Remaster',
#  "Since I've Been Loving You - Remaster",
#  'Rock and Roll - Remaster',
#  'Black Dog - Remaster',
#  'When the Levee Breaks - Remaster',
#  'Stairway to Heaven - Remaster',
#  'The Song Remains the Same - Remaster',
#  'Over the Hills and Far Away - Remaster',
#  "D'yer Mak'er - Remaster",
#  'No Quarter - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Houses of the Holy - Remaster',
#  'Kashmir - Remaster',
#  "We're Gonna Groove - 1993 Remaster",
#  'Poor Tom - 1990 Remaster',
#  "I Can't Quit You Baby - 1990 Remaster",
#  "Walter's Walk - 1993 Remaster",
#  'Ozone Baby - 1990 Remaster',
#  'Darlene - 1993 Remaster',
#  "Bonzo's Montreux - 1993 Remaster",
#  'Wearing and Tearing - 1990 Remaster',
#  'You Shook Me - 23/3/69 Top Gear; 2016 Remaster',
#  "I Can't Quit You Baby - 23/3/69 Top Gear; 2016 Remaster",
#  'Communication Breakdown - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster',
#  'Dazed and Confused - 3/23/69 Top Gear; 2016 Remaster',
#  'The Girl I Love She Got Long Black Wavy Hair - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster',
#  'What Is and What Should Never Be - 29/6/69 Top Gear; 2016 Remaster',
#  'Communication Breakdown - 29/6/69 Top Gear; 2016 Remaster',
#  'Travelling Riverside Blues - 29/6/69 Top Gear; 2016 Remaster',
#  'Whole Lotta Love - 29/6/69 Top Gear; 2016 Remaster',
#  "Somethin' Else - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster",
#  'Communication Breakdown - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  "I Can't Quit You Baby - 10/8/69 Playhouse Theatre; 2016 Remaster",
#  'You Shook Me - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  'How Many More Times - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  'Immigrant Song - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Heartbreaker - 1/4/71 Paris Theatre; 2016 Remaster',
#  "Since I've Been Loving You - 1/4/71 Paris Theatre; 2016 Remaster",
#  'Black Dog - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Dazed and Confused - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Stairway to Heaven - Live: 1/4/71 Paris Theatre; 2016 Remaster',
#  "We're Gonna Groove - Remaster",
#  'Poor Tom - Remaster',
#  "I Can't Quit You Baby - Remaster",
#  "Walter's Walk - Remaster",
#  'Ozone Baby - Remaster',
#  'Darlene - Remaster',
#  "Bonzo's Montreux - Remaster",
#  'Wearing and Tearing - Remaster',
#  "We're Gonna Groove - Alternate Mix",
#  'If It Keeps on Raining - Rough Mix',
#  "Bonzo's Montreux - Mix Construction in Progress",
#  'Baby Come on Home - Remastered',
#  'Sugar Mama - Mix',
#  'Poor Tom - Instrumental Mix',
#  'Travelling Riverside Blues (BBC Session) - Remastered',
#  'Hey, Hey, What Can I Do - Remaster',
#  'Four Hands (Four Sticks) [Bombay Orchestra]',
#  'Friends (Bombay Orchestra)',
#  "St. Tristan's Sword - Rough Mix",
#  'Desire (The Wanton Song) - Rough Mix',
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'Brandy & Coke - Trampled Under Foot; Initial / Rough Mix',
#  'Sick Again - Early Version',
#  'In My Time of Dying - Initial / Rough Mix',
#  'Houses of the Holy - Rough Mix with Overdubs',
#  'Everybody Makes It Through - In the Light; Early Version / In Transit',
#  'In the Evening - Remaster',
#  'South Bound Saurez - Remaster',
#  'Fool in the Rain - Remaster',
#  'Hot Dog - Remaster',
#  'Carouselambra - Remaster',
#  'All My Love - Remaster',
#  "I'm Gonna Crawl - Remaster",
#  'Good Times Bad Times - Live: O2 Arena, London - December 10, 2007',
#  'Ramble On - Live: O2 Arena, London - December 10, 2007',
#  'Black Dog - Live: O2 Arena, London - December 10, 2007',
#  'In My Time of Dying - Live: O2 Arena, London - December 10, 2007',
#  'For Your Life - Live: O2 Arena, London - December 10, 2007',
#  'Trampled Under Foot - Live: O2 Arena, London - December 10, 2007',
#  "Nobody's Fault but Mine - Live: O2 Arena, London - December 10, 2007",
#  'No Quarter - Live: O2 Arena, London - December 10, 2007',
#  "Since I've Been Loving You - Live: O2 Arena, London - December 10, 2007",
#  'Dazed and Confused - Live: O2 Arena, London - December 10, 2007',
#  'Stairway to Heaven - Live: O2 Arena, London - December 10, 2007',
#  'The Song Remains the Same - Live: O2 Arena, London - December 10, 2007',
#  'Misty Mountain Hop - Live: O2 Arena, London - December 10, 2007',
#  'Kashmir - Live: O2 Arena, London - December 10, 2007',
#  'Whole Lotta Love - Live: O2 Arena, London - December 10, 2007',
#  'Rock and Roll - Live: O2 Arena, London - December 10, 2007',
#  "We're Gonna Groove - Remaster",
#  'Poor Tom - Remaster',
#  "I Can't Quit You Baby - Remaster",
#  "Walter's Walk - Remaster",
#  'Ozone Baby - Remaster',
#  'Darlene - Remaster',
#  "Bonzo's Montreux - Remaster",
#  'Wearing and Tearing - Remaster',
#  'Custard Pie - 1990 Remaster',
#  'The Rover - 1993 Remaster',
#  'In My Time of Dying - 1990 Remaster',
#  'Houses of the Holy - 1990 Remaster',
#  'Trampled Under Foot - 1990 Remaster',
#  'Kashmir - 1990 Remaster',
#  'In the Light - 1990 Remaster',
#  'Bron-Yr-Aur - 1993 Remaster',
#  'Down by the Seaside - 1993 Remaster',
#  'Ten Years Gone - 1990 Remaster',
#  'Night Flight - 1993 Remaster',
#  'The Wanton Song - 1990 Remaster',
#  'Boogie with Stu - 1993 Remaster',
#  'Black Country Woman - 1993 Remaster',
#  'Sick Again - 1993 Remaster',
#  'Rock and Roll - (Live at MSG 1973) [Remaster]',
#  'Celebration Day - (Live at MSG 1973) [Remaster]',
#  'Black Dog - (Live at MSG 1973) [Remaster]',
#  'Over the Hills and Far Away - (Live at MSG 1973) [Remaster]',
#  'Misty Mountain Hop - (Live at MSG 1973) [Remaster]',
#  "Since I've Been Loving You - (Live at MSG 1973) [Remaster]",
#  'No Quarter - (Live at MSG 1973) [Remaster]',
#  'The Song Remains the Same - (Live at MSG 1973) [Remaster]',
#  'The Rain Song - (Live at MSG 1973) [Remaster]',
#  'The Ocean - Live at MSG 1973; 2018 Remaster',
#  'Dazed and Confused - (Live at MSG 1973) [Remaster]',
#  'Stairway to Heaven - (Live at MSG 1973) [Remaster]',
#  'Moby Dick - (Live at MSG 1973) [Remaster]',
#  'Heartbreaker - (Live at MSG 1973) [Remaster]',
#  'Whole Lotta Love - (Live at MSG 1973) [Remaster]',
#  'In the Evening - Remaster',
#  'South Bound Saurez - Remaster',
#  'Fool in the Rain - Remaster',
#  'Hot Dog - Remaster',
#  'Carouselambra - Remaster',
#  'All My Love - Remaster',
#  "I'm Gonna Crawl - Remaster",
#  'In the Evening - Rough Mix',
#  'Southbound Piano (South Bound Saurez) - Rough Mix',
#  'Fool in the Rain - Rough Mix',
#  'Hot Dog - Rough Mix',
#  'The Epic (Carouselambra) - Rough Mix',
#  'The Hook (All My Love) - Rough Mix',
#  "Blot (I'm Gonna Crawl) - Rough Mix",
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'Brandy & Coke - Trampled Under Foot; Initial / Rough Mix',
#  'Sick Again - Early Version',
#  'In My Time of Dying - Initial / Rough Mix',
#  'Houses of the Holy - Rough Mix with Overdubs',
#  'Everybody Makes It Through - In the Light; Early Version / In Transit',
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'Brandy & Coke - Trampled Under Foot; Initial / Rough Mix',
#  'Sick Again - Early Version',
#  'In My Time of Dying - Initial / Rough Mix',
#  'Houses of the Holy - Rough Mix with Overdubs',
#  'Everybody Makes It Through - In the Light; Early Version / In Transit',
#  'Achilles Last Stand - 1990 Remaster',
#  'For Your Life - 1990 Remaster',
#  'Royal Orleans - 1993 Remaster',
#  "Nobody's Fault but Mine - 1990 Remaster",
#  'Candy Store Rock - 1990 Remaster',
#  'Hots on for Nowhere - 1993 Remaster',
#  'Tea for One - 1993 Remaster',
#  'LA Drone - Live 1972; 2018 Remaster',
#  'Immigrant Song - Live 1972; 2018 Remaster',
#  'Heartbreaker - Live 1972; 2018 Remaster',
#  'Black Dog - Live 1972; 2018 Remaster',
#  'Over the Hills and Far Away - Live 1972; 2018 Remaster',
#  "Since I've Been Loving You - Live 1972; 2018 Remaster",
#  'Stairway to Heaven - Live 1972; 2018 Remaster',
#  'Going to California - Live 1972; 2018 Remaster',
#  "That's The Way - Live 1972; 2018 Remaster",
#  'Bron-Y-Aur Stomp - Live 1972; 2018 Remaster',
#  'Dazed and Confused - Live 1972; 2018 Remaster',
#  'What Is and What Should Never Be (Live) - Live 1972; 2018 Remaster',
#  'Dancing Days - Live 1972; 2018 Remaster',
#  'Moby Dick - Live 1972; 2018 Remaster',
#  'Whole Lotta Love - Live 1972; 2018 Remaster',
#  'Rock and Roll - Live 1972; 2018 Remaster',
#  'The Ocean - Live 1972; 2018 Remaster',
#  'Bring It on Home / Bring It on Back - Live 1972; 2018 Remaster',
#  'In the Evening - 1990 Remaster',
#  'South Bound Saurez - 1993 Remaster',
#  'Fool in the Rain - 1990 Remaster',
#  'Hot Dog - 1993 Remaster',
#  'Carouselambra - 1993 Remaster',
#  'All My Love - 1990 Remaster',
#  "I'm Gonna Crawl - 1990 Remaster",
#  'Achilles Last Stand - Remaster',
#  'For Your Life - Remaster',
#  'Royal Orleans - Remaster',
#  "Nobody's Fault but Mine - Remaster",
#  'Candy Store Rock - Remaster',
#  'Hots on for Nowhere - Remaster',
#  'Tea for One - Remaster',
#  'Custard Pie - Remaster',
#  'The Rover - Remaster',
#  'In My Time of Dying - Remaster',
#  'Houses of the Holy - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Kashmir - Remaster',
#  'In the Light - Remaster',
#  'Bron-Yr-Aur - Remaster',
#  'Down by the Seaside - Remaster',
#  'Ten Years Gone - Remaster',
#  'Night Flight - Remaster',
#  'The Wanton Song - Remaster',
#  'Boogie with Stu - Remaster',
#  'Black Country Woman - Remaster',
#  'Sick Again - Remaster',
#  'The Song Remains the Same - Remaster',
#  'The Rain Song - Remaster',
#  'Over the Hills and Far Away - Remaster',
#  'The Crunge - Remaster',
#  'Dancing Days - Remaster',
#  "D'yer Mak'er - Remaster",
#  'No Quarter - Remaster',
#  'The Ocean - Remaster',
#  'The Song Remains the Same - Guitar Overdub Reference Mix',
#  'The Rain Song - Mix Minus Piano',
#  'Over the Hills and Far Away - Guitar Mix Backing Track',
#  'The Crunge - Rough Mix - Keys Up',
#  'Dancing Days - Rough Mix with Vocal',
#  'No Quarter - Rough Mix with JPJ Keyboard Overdubs - No Vocal',
#  'The Ocean - Working Mix',
#  'Achilles Last Stand - Remaster',
#  'For Your Life - Remaster',
#  'Royal Orleans - Remaster',
#  "Nobody's Fault but Mine - Remaster",
#  'Candy Store Rock - Remaster',
#  'Hots on for Nowhere - Remaster',
#  'Tea for One - Remaster',
#  'Two Ones Are Won - Achilles Last Stand Reference Mix',
#  'For Your Life - Reference Mix',
#  '10 Ribs & All / Carrot Pod Pod (Pod) - Reference Mix',
#  'Royal Orleans - Reference Mix',
#  'Hots on for Nowhere - Reference Mix',
#  "We're Gonna Groove - 1993 Remaster",
#  'Poor Tom - 1990 Remaster',
#  "I Can't Quit You Baby - 1990 Remaster",
#  "Walter's Walk - 1993 Remaster",
#  'Ozone Baby - 1990 Remaster',
#  'Darlene - 1993 Remaster',
#  "Bonzo's Montreux - 1993 Remaster",
#  'Wearing and Tearing - 1990 Remaster',
#  "We're Gonna Groove - Remaster",
#  'Poor Tom - Remaster',
#  "I Can't Quit You Baby - Remaster",
#  "Walter's Walk - Remaster",
#  'Ozone Baby - Remaster',
#  'Darlene - Remaster',
#  "Bonzo's Montreux - Remaster",
#  'Wearing and Tearing - Remaster',
#  "We're Gonna Groove - Alternate Mix",
#  'If It Keeps on Raining - Rough Mix',
#  "Bonzo's Montreux - Mix Construction in Progress",
#  'Baby Come on Home - Remastered',
#  'Sugar Mama - Mix',
#  'Poor Tom - Instrumental Mix',
#  'Travelling Riverside Blues (BBC Session) - Remastered',
#  'Hey, Hey, What Can I Do - Remaster',
#  'Four Hands (Four Sticks) [Bombay Orchestra]',
#  'Friends (Bombay Orchestra)',
#  "St. Tristan's Sword - Rough Mix",
#  'Desire (The Wanton Song) - Rough Mix',
#  'You Shook Me - 23/3/69 Top Gear; 2016 Remaster',
#  "I Can't Quit You Baby - 23/3/69 Top Gear; 2016 Remaster",
#  'Communication Breakdown - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster',
#  'Dazed and Confused - 3/23/69 Top Gear; 2016 Remaster',
#  'The Girl I Love She Got Long Black Wavy Hair - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster',
#  'What Is and What Should Never Be - 29/6/69 Top Gear; 2016 Remaster',
#  'Communication Breakdown - 29/6/69 Top Gear; 2016 Remaster',
#  'Travelling Riverside Blues - 29/6/69 Top Gear; 2016 Remaster',
#  'Whole Lotta Love - 29/6/69 Top Gear; 2016 Remaster',
#  "Somethin' Else - Live on Tasty Pop Sundae from BBC Sessions; 2016 Remaster",
#  'Communication Breakdown - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  "I Can't Quit You Baby - 10/8/69 Playhouse Theatre; 2016 Remaster",
#  'You Shook Me - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  'How Many More Times - 10/8/69 Playhouse Theatre; 2016 Remaster',
#  'Immigrant Song - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Heartbreaker - 1/4/71 Paris Theatre; 2016 Remaster',
#  "Since I've Been Loving You - 1/4/71 Paris Theatre; 2016 Remaster",
#  'Black Dog - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Dazed and Confused - 1/4/71 Paris Theatre; 2016 Remaster',
#  'Stairway to Heaven - Live: 1/4/71 Paris Theatre; 2016 Remaster',
#  'Good Times Bad Times - Remaster',
#  'Communication Breakdown - Remaster',
#  'Dazed and Confused - Remaster',
#  "Babe I'm Gonna Leave You - Remaster",
#  'Whole Lotta Love - Remaster',
#  'Ramble On - Remaster',
#  'Heartbreaker - Remaster',
#  'Immigrant Song - Remaster',
#  "Since I've Been Loving You - Remaster",
#  'Rock and Roll - Remaster',
#  'Black Dog - Remaster',
#  'When the Levee Breaks - Remaster',
#  'Stairway to Heaven - Remaster',
#  'The Song Remains the Same - Remaster',
#  'Over the Hills and Far Away - Remaster',
#  "D'yer Mak'er - Remaster",
#  'No Quarter - Remaster',
#  'Trampled Under Foot - Remaster',
#  'Houses of the Holy - Remaster',
#  'Kashmir - Remaster',
#  'Custard Pie - 1990 Remaster',
#  'The Rover - 1993 Remaster',
#  'In My Time of Dying - 1990 Remaster',
#  'Houses of the Holy - 1990 Remaster',
#  'Trampled Under Foot - 1990 Remaster',
#  'Kashmir - 1990 Remaster',
#  'In the Light - 1990 Remaster',
#  'Bron-Yr-Aur - 1993 Remaster',
#  'Down by the Seaside - 1993 Remaster',
#  'Ten Years Gone - 1990 Remaster',
#  'Night Flight - 1993 Remaster',
#  'The Wanton Song - 1990 Remaster',
#  'Boogie with Stu - 1993 Remaster',
#  'Black Country Woman - 1993 Remaster',
#  'Sick Again - 1993 Remaster']

# %%
TRACKS_NAMES = []

# %%
# Now let's see how much it takes

# %%
# %%timeit -n 1 -r 1
with futures.ThreadPoolExecutor(workers) as executor:
    to_do = []
    for album_id in sorted(albums_id):
        future = executor.submit(get_tracks, album_id)
        to_do.append(future)
    results = []
    for future in futures.as_completed(to_do):
        res = future.result()
        TRACKS_NAMES.extend(res)
# Out:
# {'href': 'https://api.spotify.com/v1/albums/1lZahjeu4AhPkg9JARZr5F/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 253866, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5cgL1YdlGWR5KfncpAGFQk'}, 'href': 'https://api.spotify.com/v1/tracks/5cgL1YdlGWR5KfncpAGFQk', 'id': '5cgL1YdlGWR5KfncpAGFQk', 'is_local': False, 'name': 'Custard Pie - 1990 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/6d4b120019a5a262fa035483634dab9b767465ab?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5cgL1YdlGWR5KfncpAGFQk'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 336906, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/4hLQfgtzEyxme6w5GiwAEy'}, 'href': 'https://api.spotify.com/v1/tracks/4hLQfgtzEyxme6w5GiwAEy', 'id': '4hLQfgtzEyxme6w5GiwAEy', 'is_local': False, 'name': 'The Rover - 1993 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/f9ed3497704c0097240f0fef7591c39f5c70b0fb?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:4hLQfgtzEyxme6w5GiwAEy'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 665600, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5g9VOUgrn7ozYE3ZQm8w41'}, 'href': 'https://api.spotify.com/v1/tracks/5g9VOUgrn7ozYE3ZQm8w41', 'id': '5g9VOUgrn7ozYE3ZQm8w41', 'is_local': False, 'name': 'In My Time of Dying ...
# {'href': 'https://api.spotify.com/v1/albums/26tH0kjUhkxBEd3ipGkx3Y/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 255701, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5HlLgmHL8qafp46jMtlxZJ'}, 'href': 'https://api.spotify.com/v1/tracks/5HlLgmHL8qafp46jMtlxZJ', 'id': '5HlLgmHL8qafp46jMtlxZJ', 'is_local': False, 'name': 'Custard Pie - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/26073c91a3069fa0b9eeadf7ff06cdc010e58f58?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5HlLgmHL8qafp46jMtlxZJ'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 339474, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/4r8AQvzullpWTDpgv70KxD'}, 'href': 'https://api.spotify.com/v1/tracks/4r8AQvzullpWTDpgv70KxD', 'id': '4r8AQvzullpWTDpgv70KxD', 'is_local': False, 'name': 'The Rover - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/513d5a41613bcf83b4bfe53e4dc09104d781161f?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:4r8AQvzullpWTDpgv70KxD'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 668440, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/4EUe6BsZm5wZLxOTaV3kDX'}, 'href': 'https://api.spotify.com/v1/tracks/4EUe6BsZm5wZLxOTaV3kDX', 'id': '4EUe6BsZm5wZLxOTaV3kDX', 'is_local': False, 'name': 'In My Time of Dying - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/5c62a8f627c5c04c2d0fe0edc9c0f167da8014e7?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:4EUe6BsZm5wZLxOTaV3kDX'}, {'artists': [{'external_urls': {'spotify': 'https://open ...
# {'href': 'https://api.spotify.com/v1/albums/23FJTTzUIUjhmimOE2CTX2/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['JP'], 'disc_number': 1, 'duration_ms': 255701, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2y0l7GpFGPLXjk9rrmzecj'}, 'href': 'https://api.spotify.com/v1/tracks/2y0l7GpFGPLXjk9rrmzecj', 'id': '2y0l7GpFGPLXjk9rrmzecj', 'is_local': False, 'name': 'Custard Pie - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/26073c91a3069fa0b9eeadf7ff06cdc010e58f58?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2y0l7GpFGPLXjk9rrmzecj'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['JP'], 'disc_number': 1, 'duration_ms': 339474, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/58pXcVpaKxmjViTw4ixYLa'}, 'href': 'https://api.spotify.com/v1/tracks/58pXcVpaKxmjViTw4ixYLa', 'id': '58pXcVpaKxmjViTw4ixYLa', 'is_local': False, 'name': 'The Rover - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/513d5a41613bcf83b4bfe53e4dc09104d781161f?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:58pXcVpaKxmjViTw4ixYLa'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['JP'], 'disc_number': 1, 'duration_ms': 668440, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2IS9AdXu3zWjY5FCslQyOa'}, 'href': 'https://api.spotify.com/v1/tracks/2IS9AdXu3zWjY5FCslQyOa', 'id': '2IS9AdXu3zWjY5FCslQyOa', 'is_local': False, 'name': 'In My Time of Dying - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/5c62a8f627c5c04c2d0fe0edc9c0f167da8014e7?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:2IS9AdXu3zWjY5FCslQyOa'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['JP'], 'disc_number': 1, 'duration_ms': 244686, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2pkiN0XEcHm90sNjoWnEtv'}, 'href': 'https://api.spotify.com/v1/tracks/2pkiN0XEcHm90sNjoWnEtv', 'id': '2pkiN0XEcHm90sNjoWnEtv', 'is_local': False, 'name': 'Houses of the Holy - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/4a859dd37ca683bcee241a2f582e8ce5c1115104?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:2pkiN0XEcHm90sNjoWnEtv'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['JP'], 'disc_number': 1, 'duration_ms': 336835, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/71mwBgYAlFsg4haHqODDbY'}, 'href': 'https://api.spotify.com/v1/tracks/71mwBgYAlFsg4haHqODDbY', 'id': '7 ...
# {'href': 'https://api.spotify.com/v1/albums/0ui4S0TZghkf1d1Wz0oWpk/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 236333, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2SxJwk01jPkt6JnzpuY2oT'}, 'href': 'https://api.spotify.com/v1/tracks/2SxJwk01jPkt6JnzpuY2oT', 'id': '2SxJwk01jPkt6JnzpuY2oT', 'is_local': False, 'name': 'Rock and Roll - (Live at MSG 1973) [Remaster]', 'preview_url': 'https://p.scdn.co/mp3-preview/3e8ddb970818df0fbb07de07a328c7cd90c06ea8?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2SxJwk01jPkt6JnzpuY2oT'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 217613, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/3AKELG5VNBxeRt4b42hRjI'}, 'href': 'https://api.spotify.com/v1/tracks/3AKELG5VNBxeRt4b42hRjI', 'id': '3AKELG5VNBxeRt4b42hRjI', 'is_local': False, 'name': 'Celebration Day - (Live at MSG 1973) [Remaster]', 'preview_url': 'https://p.scdn.co/mp3-preview/ff6969021903b8366d6a9aab8f6ea8675eb5d393?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:3AKELG5VNBxeRt4b42hRjI'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 226280, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/6CtTQxzJXMQuujhe0RX3UL'}, 'href': 'https://api.spotify.com/v1/tracks/6CtTQxzJXMQuujhe0RX3UL', 'id ...
# {'href': 'https://api.spotify.com/v1/albums/6vSiY2OVanKKforfEOT2PD/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 631720, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/0BochXUxV1vjmkGIfVRXpi'}, 'href': 'https://api.spotify.com/v1/tracks/0BochXUxV1vjmkGIfVRXpi', 'id': '0BochXUxV1vjmkGIfVRXpi', 'is_local': False, 'name': 'Achilles Last Stand - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/fd6c719cf3000d746b531460d14ec32d3fc632f4?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:0BochXUxV1vjmkGIfVRXpi'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 385080, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/0vqy9wH3X3RjgrnmGaHfIW'}, 'href': 'https://api.spotify.com/v1/tracks/0vqy9wH3X3RjgrnmGaHfIW', 'id': '0vqy9wH3X3RjgrnmGaHfIW', 'is_local': False, 'name': 'For Your Life - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/ef276036189689bf1940c15527ac8c1cff9d58e9?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:0vqy9wH3X3RjgrnmGaHfIW'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 179226, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/51fBpLsMRfOqQX1rWLXHgD'}, 'href': 'https://api.spotify.com/v1/tracks/51fBpLsMRfOqQX1rWLXHgD', 'id': '51fBpLsMRfOqQX1rWLXHgD', 'is_local': False, 'name': 'Royal Orleans - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/e38b1072b8a379612015aaa6ff0fc6653d05e3a0?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:51fBpLsMRfOqQX1rWLXHgD'}, {'artists': [{'external_urls': {'spotify': 'https: ...
# {'href': 'https://api.spotify.com/v1/albums/5WRmchevXvk5eXPT0gEuTL/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 157840, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5h32ElaHxUjVCyMRb5snh2'}, 'href': 'https://api.spotify.com/v1/tracks/5h32ElaHxUjVCyMRb5snh2', 'id': '5h32ElaHxUjVCyMRb5snh2', 'is_local': False, 'name': "We're Gonna Groove - 1993 Remaster", 'preview_url': 'https://p.scdn.co/mp3-preview/dc5f0f29f39218963d21d6bf790f22f703a131b5?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5h32ElaHxUjVCyMRb5snh2'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 182093, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/1TdeOVizQgzr4ul5BxfTlc'}, 'href': 'https://api.spotify.com/v1/tracks/1TdeOVizQgzr4ul5BxfTlc', 'id': '1TdeOVizQgzr4ul5BxfTlc', 'is_local': False, 'name': 'Poor Tom - 1990 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/a331c323276c156f82fb5f5924c54c562ebd6e9e?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:1TdeOVizQgzr4ul5BxfTlc'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 258133, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/7lDUgEhAtLsPpnWxtGqDes'}, 'href': 'https://api.spotify.com/v1/tracks/7lDUgEhAtLsPpnWxtGqDes', 'id': '7lDUgEhAtLsPpnWxtGqDes', 'is_local': False, 'name': "I Can't Quit  ...
# {'href': 'https://api.spotify.com/v1/albums/4wVHvawxZy52Oemd4sGyUm/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 407240, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2fvLQe9ZlRaEJ5o4sG3TbM'}, 'href': 'https://api.spotify.com/v1/tracks/2fvLQe9ZlRaEJ5o4sG3TbM', 'id': '2fvLQe9ZlRaEJ5o4sG3TbM', 'is_local': False, 'name': 'In the Evening - 1990 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/9974698291678c96c18982efebfc23c50bbed68f?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2fvLQe9ZlRaEJ5o4sG3TbM'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 252733, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/7v3l2PEaxnex3NylNusT4Y'}, 'href': 'https://api.spotify.com/v1/tracks/7v3l2PEaxnex3NylNusT4Y', 'id': '7v3l2PEaxnex3NylNusT4Y', 'is_local': False, 'name': 'South Bound Saurez - 1993 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/94587a26efefaf033fd1113aac27a1424cba7e70?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:7v3l2PEaxnex3NylNusT4Y'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 372893, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/62p6fF2r4NY6pwZbxxvmr8'}, 'href': 'https://api.spotify.com/v1/tracks/62p6fF2r4NY6pwZbxxvmr8', 'id': '62p6fF2r4NY6pwZbxxvmr8', 'is_local': False, 'name': 'Fool in ...
# {'href': 'https://api.spotify.com/v1/albums/3otvl9PN3kOgk5uwAh1CBL/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 14706, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/7F9HDTp5qh7iDxxGX4D8Ab'}, 'href': 'https://api.spotify.com/v1/tracks/7F9HDTp5qh7iDxxGX4D8Ab', 'id': '7F9HDTp5qh7iDxxGX4D8Ab', 'is_local': False, 'name': 'LA Drone - Live 1972; 2018 Remaster', 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:7F9HDTp5qh7iDxxGX4D8Ab'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 221733, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2aH2dcPnwoQwhLsXFezU2r'}, 'href': 'https://api.spotify.com/v1/tracks/2aH2dcPnwoQwhLsXFezU2r', 'id': '2aH2dcPnwoQwhLsXFezU2r', 'is_local': False, 'name': 'Immigrant Song - Live 1972; 2018 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/738e6316d10218eab3b5a050e2319674ff46900d?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:2aH2dcPnwoQwhLsXFezU2r'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 443986, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2u7UUC5j1AStZ72gtxmXca'}, 'href': 'https://api.spotify.com/v1/tracks/2u7UUC5j1AStZ72gtxmXca', 'id': '2u7UUC5j1AStZ72gtxmXca', 'is_local': False, 'name': 'Heartbreaker - Live 1972; 2018 Remaster', 'preview_url': 'https:/ ...
# {'href': 'https://api.spotify.com/v1/albums/1W5CtQ7Ng0kP3lXyz7PIT2/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 413906, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5OGPjlTOXvKFhnCy9zSdpv'}, 'href': 'https://api.spotify.com/v1/tracks/5OGPjlTOXvKFhnCy9zSdpv', 'id': '5OGPjlTOXvKFhnCy9zSdpv', 'is_local': False, 'name': 'In the Evening - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/ad5c41b4b65b16e79141a74be9110f6156b3d50f?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5OGPjlTOXvKFhnCy9zSdpv'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 253920, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/23FeHDJaegIZF0dpH4x1Tf'}, 'href': 'https://api.spotify.com/v1/tracks/23FeHDJaegIZF0dpH4x1Tf', 'id': '23FeHDJaegIZF0dpH4x1Tf', 'is_local': False, 'name': 'South Bound Saurez - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/2b9deaf78f21347a52d709a3b8c589ad5368df72?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:23FeHDJaegIZF0dpH4x1Tf'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 370920, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/3i25w2HOWoafnTIiWJCL71'}, 'href': 'https://api.spotify.com/v1/tracks/3i25w2HOWoafnTIiWJCL71', 'id': '3i25w2HOWoafnTIiWJCL71', 'is_local': False, 'name': 'Fool in the Rain - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/dd164203179507cd973c174349d63cf33f615591?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:3i25w2HOWoafnTIiWJCL71'}, {'artists': [{'external_urls': {'spotify': 'htt ...
#
# {'href': 'https://api.spotify.com/v1/albums/3uhD8hNpb0m3iIZ18RHH5u/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 631720, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/1ibHApXtb0pgplmNDRLHrJ'}, 'href': 'https://api.spotify.com/v1/tracks/1ibHApXtb0pgplmNDRLHrJ', 'id': '1ibHApXtb0pgplmNDRLHrJ', 'is_local': False, 'name': 'Achilles Last Stand - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/fd6c719cf3000d746b531460d14ec32d3fc632f4?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:1ibHApXtb0pgplmNDRLHrJ'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 385080, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/6ly5DBm7QhjU8RQWl2neJg'}, 'href': 'https://api.spotify.com/v1/tracks/6ly5DBm7QhjU8RQWl2neJg', 'id': '6ly5DBm7QhjU8RQWl2neJg', 'is_local': False, 'name': 'For Your Life - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/ef276036189689bf1940c15527ac8c1cff9d58e9?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:6ly5DBm7QhjU8RQWl2neJg'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 179226, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5zTX9sl93oTNuUiOmgq5Cc'}, 'href': 'https://api.spotify.com/v1/tracks/5zTX9sl93oTNuUiOmgq5Cc', 'id': '5zTX9sl93oTNuUiOmgq5Cc', 'is_local': False, 'name': 'Royal Orleans - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/e38b1072b8a379612015aaa6ff0fc6653d05e3a0?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:5zTX9sl93oTNuUiOmgq5Cc'}, {'artists': [{'external_urls': {'spotify': 'https: ...
# {'href': 'https://api.spotify.com/v1/albums/7gS8ozSkvPW3VBPLnXOZ7S/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 329093, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/39HPNIdWUse9mLDio9dxwK'}, 'href': 'https://api.spotify.com/v1/tracks/39HPNIdWUse9mLDio9dxwK', 'id': '39HPNIdWUse9mLDio9dxwK', 'is_local': False, 'name': 'The Song Remains the Same - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/9b8167fb3191700969ebdf5baa6b3af413dd6086?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:39HPNIdWUse9mLDio9dxwK'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 459093, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/69lH8EQMuHWx9f8QKpiddJ'}, 'href': 'https://api.spotify.com/v1/tracks/69lH8EQMuHWx9f8QKpiddJ', 'id': '69lH8EQMuHWx9f8QKpiddJ', 'is_local': False, 'name': 'The Rain Song - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/063ea20efd9ba745f533f1c07ff0a08590f02ed9?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:69lH8EQMuHWx9f8QKpiddJ'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 290933, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/1S1vypzJvsPQD3yriNFNdu'}, 'href': 'https://api.spotify.com/v1/tracks/1S1vypzJvsPQD3yriNFNdu', 'id': '1S1vypzJvsPQD3yriNFNdu', 'is ...
#
# ...
# {'href': 'https://api.spotify.com/v1/albums/228mANuRrV20jS5DCA0eER/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 158413, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/50B4cVWKkqpSTxWG9xhMXo'}, 'href': 'https://api.spotify.com/v1/tracks/50B4cVWKkqpSTxWG9xhMXo', 'id': '50B4cVWKkqpSTxWG9xhMXo', 'is_local': False, 'name': "We're Gonna Groove - Remaster", 'preview_url': 'https://p.scdn.co/mp3-preview/e3d63262c725c672807d663abc0d68ac463fa88d?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:50B4cVWKkqpSTxWG9xhMXo'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 182413, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/6oqciM0WBIxBmRPoOL4iNF'}, 'href': 'https://api.spotify.com/v1/tracks/6oqciM0WBIxBmRPoOL4iNF', 'id': '6oqciM0WBIxBmRPoOL4iNF', 'is_local': False, 'name': 'Poor Tom - Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/896281475331139c551d0c1364d155520e7520b9?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:6oqciM0WBIxBmRPoOL4iNF'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KZ', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'RO', 'RS', 'RU', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 258173, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/596s59vwvjBLQ6OAQc9TQR'}, 'href': 'https://api.spotify.com/v1/tracks/596s59vwvjBLQ6OAQc9TQR', 'id': '596s59vwvjBLQ6OAQc9TQR', 'is_local': False, 'name': "I Can't Quit You Baby - Remaster", 'preview_url': 'https://p.scdn.co/mp3-preview/52819f06926970aed844f4dc9bbe6f87e6854e70?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:596s59vwvjBLQ6OAQc9TQR'}, {'artists': [{'external_urls': {'spotify': 'http ...
# {'href': 'https://api.spotify.com/v1/albums/0kTe1sQd9yhDsdG2Zth7X6/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 191560, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/7wGaViRu4g24CDqUcnJrGp'}, 'href': 'https://api.spotify.com/v1/tracks/7wGaViRu4g24CDqUcnJrGp', 'id': '7wGaViRu4g24CDqUcnJrGp', 'is_local': False, 'name': 'Good Times Bad Times - Live: O2 Arena, London - December 10, 2007', 'preview_url': 'https://p.scdn.co/mp3-preview/604d0ade92be93ea7c3ef0fd9b5b33e87dda8883?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:7wGaViRu4g24CDqUcnJrGp'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 344560, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/1kOfZShwvYeN4b4UocSGMm'}, 'href': 'https://api.spotify.com/v1/tracks/1kOfZShwvYeN4b4UocSGMm', 'id': '1kOfZShwvYeN4b4UocSGMm', 'is_local': False, 'name': 'Ramble On - Live: O2 Arena, London - December 10, 2007', 'preview_url': 'https://p.scdn.co/mp3-preview/5b810af9d0bcba5de7bb6b72fd4abdb52b76f6b2?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:1kOfZShwvYeN4b4UocSGMm'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 353400, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5xAWsRDWBaEv0aFsAAqJBD'}, 'href': 'https://api.spotify.com/v1/tracks/5xAWsRDWBaEv0aFsAAqJBD', 'id': '5xAWs ...
# {'href': 'https://api.spotify.com/v1/albums/3xiPkaTzfC48CcsXYgz5v0/tracks?offset=0&limit=20', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 622000, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/5gwign6hATXgMHxYrRix9L'}, 'href': 'https://api.spotify.com/v1/tracks/5gwign6hATXgMHxYrRix9L', 'id': '5gwign6hATXgMHxYrRix9L', 'is_local': False, 'name': 'Achilles Last Stand - 1990 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/376b2d9b68addec5938b2cdeabeb613f3a3cb2da?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5gwign6hATXgMHxYrRix9L'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 384106, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2hXhzBwIcrfQQUdelpLZXH'}, 'href': 'https://api.spotify.com/v1/tracks/2hXhzBwIcrfQQUdelpLZXH', 'id': '2hXhzBwIcrfQQUdelpLZXH', 'is_local': False, 'name': 'For Your Life - 1990 Remaster', 'preview_url': 'https://p.scdn.co/mp3-preview/77d41674fc22e886240a739d73850f5a398895dc?cid=1e8df497a8254e4b8ee14e464f164d71', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:2hXhzBwIcrfQQUdelpLZXH'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'}, 'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp', 'id': '36QJpDe2go2KgaRleHCDTp', 'name': 'Led Zeppelin', 'type': 'artist', 'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 178266, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2wjONj1QX8czcIpjwxyKHA'}, 'href': 'https://api.spotify.com/v1/tracks/2wjONj1QX8czcIpjwxyKHA', 'id': '2wjONj1QX8czcIpjwxyKHA', 'is_local': False, 'name': 'Royal O ...
# 610 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# As you see it does the same task faster.
